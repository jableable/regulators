# %% [markdown]
# In this notebook we clean the weather data collected from the [Climate Database Online](https://www.ncei.noaa.gov/cdo-web/search) compiled by NOAA.
#
# These datasets contain:
# - Facility ID [STATION]: The station ID of the weather monitoring facility.
# - Facility Name [NAME]: The name and state of the weather monitoring facility.
# - Date [DATE]: The year and month of the measurement in YYYY-MM format.
# - Rain [PRCP]: The amount of rain in inches measured at the facility.
# - Snow Total [SNOW]: The aamount of snow in inches measured by the facility.

# %% [markdown]
# This notebook expects data to be stored in a directory `SharedData` at the root of the git repo. This directory should have the same structure as the `Data` folder stored on the project Google Drive.

# %%
# Import packages
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import the data
df1 = pd.read_csv(os.path.join("..", "..", "SharedData", "Weather (1990-2019)", "AL-GA,OK,OR.csv"))
df2 = pd.read_csv(os.path.join("..", "..", "SharedData", "Weather (1990-2019)", "HI-MN.csv"))
df3 = pd.read_csv(os.path.join("..", "..", "SharedData", "Weather (1990-2019)", "MS-OH.csv"))
df4 = pd.read_csv(os.path.join("..", "..", "SharedData", "Weather (1990-2019)", "PA-WY.csv"))
df = pd.concat([df1, df2, df3, df4])
df.sample(5)
# Out:
#           STATION                                               NAME     DATE  \
# 2157  USW00014742            BURLINGTON INTERNATIONAL AIRPORT, VT US  2019-10
# 42    USW00003940               JACKSON INTERNATIONAL AIRPORT, MS US  1993-07
# 3546  USW00013994      ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US  2016-03
# 3719  USW00024127        SALT LAKE CITY INTERNATIONAL AIRPORT, UT US  1999-12
# 2552  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US  2002-04
#
#       PRCP  SNOW  TAVG
# 2157  8.50   0.0  52.1
# 42    6.99   0.0  82.5
# 3546  2.29   0.3  53.0
# 3719  1.84  18.0  31.0
# 2552  4.07   0.0  56.7

# %%
# Extract state from facility name
df["state"] = df.NAME.str[-5:-3]
df.sample(5)
# Out:
#           STATION                                               NAME     DATE  \
# 3516  USW00013994      ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US  2013-09
# 3206  USW00093730         ATLANTIC CITY INTERNATIONAL AIRPORT, NJ US  2017-11
# 904   USC00120784              BLOOMINGTON INDIANA UNIVERSITY, IN US  2014-02
# 1528  USW00014765  RHODE ISLAND T.F. GREEN INTERNATIONAL AIRPORT,...  1997-05
# 3085  USW00014839                  MILWAUKEE MITCHELL AIRPORT, WI US  2007-02
#
#       PRCP  SNOW  TAVG state
# 3516  2.74   0.0  73.9    MO
# 3206  2.42   0.0  46.8    NJ
# 904   2.31   7.1  24.4    IN
# 1528  2.68   NaN  55.4    RI
# 3085  1.37  23.8  17.7    WI

# %%
# Rename columns to be more consistent
df = df.rename(columns={"DATE":"date", "PRCP":"prcp", "SNOW":"snow", "TAVG":"tavg"})
df.sample(5)
# Out:
#           STATION                                           NAME     date  \
# 4353  USW00024157           SPOKANE INTERNATIONAL AIRPORT, WA US  1992-10
# 3043  USW00093730     ATLANTIC CITY INTERNATIONAL AIRPORT, NJ US  2004-04
# 4625  USW00024157           SPOKANE INTERNATIONAL AIRPORT, WA US  2015-06
# 3521  USW00013994  ST LOUIS LAMBERT INTERNATIONAL AIRPORT, MO US  2014-02
# 1625  USW00014764                        PORTLAND JETPORT, ME US  2014-07
#
#       prcp  snow  tavg state
# 4353  0.82   0.0  49.5    WA
# 3043  4.71   0.1  52.2    NJ
# 4625  0.07   0.0  71.5    WA
# 3521  1.48   5.8  27.5    MO
# 1625  6.12   0.0  69.8    ME

# %%
# Verify no duplicate dates
abbreviations = [
    "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
    "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
    "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
    "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
    "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
]
count = 0
for i in abbreviations:
    if len(df[df.state==i].date.unique()) != len(df[df.state==i]):
        print(i)
        count += 1
if not count:
    print("All dates are unique for each state!")
# Out:
# All dates are unique for each state!

# %% [markdown]
# A brief aside here--let's take a look at the NA values to try and better understand what needs cleaning.

# %%
# ACheck the number of NA values
df.isna().sum()
# Out:
# STATION       0
# NAME          0
# date          0
# prcp         14
# snow       2235
# tavg         30
# state         0
# dtype: int64

# %%
# See the precipitation values
df[df.prcp.isna()]
# Out:
#           STATION                                             NAME     date  \
# 3605  USC00072730                                     DOVER, DE US  2011-11
# 3631  USC00072730                                     DOVER, DE US  2014-01
# 3642  USC00072730                                     DOVER, DE US  2014-12
# 3708  USC00072730                                     DOVER, DE US  2020-10
# 3709  USC00072730                                     DOVER, DE US  2020-11
# 106   USW00094817  PONTIAC OAKLAND CO INTERNATIONAL AIRPORT, MI US  2007-08
# 107   USW00094817  PONTIAC OAKLAND CO INTERNATIONAL AIRPORT, MI US  2007-09
# 883   USC00120784            BLOOMINGTON INDIANA UNIVERSITY, IN US  2012-05
# 970   USC00120784            BLOOMINGTON INDIANA UNIVERSITY, IN US  2019-08
# 972   USC00120784            BLOOMINGTON INDIANA UNIVERSITY, IN US  2019-10
# 1006  USC00516128                     MANOA LYON ARBO 785.2, HI US  1992-08
# 1709  USC00102942                                EMMETT 2 E, ID US  1991-07
# 2843  USW00093821          LOUISVILLE INTERNATIONAL AIRPORT, KY US  1996-07
# 781   USW00014916         GRAND FORKS INTERNATIONAL AIRPORT, ND US  1995-02
#
#       prcp  snow  tavg state
# 3605   NaN   NaN  51.9    DE
# 3631   NaN   NaN  31.5    DE
# 3642   NaN   0.0  41.7    DE
# 3708   NaN   NaN   NaN    DE
# 3709   NaN   NaN   NaN    DE
# 106    NaN   NaN  72.8    MI
# 107    NaN   NaN  65.4    MI
# 883    NaN   0.0  69.0    IN
# 970    NaN   0.0   NaN    IN
# 972    NaN   0.0   NaN    IN
# 1006   NaN   NaN   NaN    HI
# 1709   NaN   0.0   NaN    ID
# 2843   NaN   NaN  75.8    KY
# 781    NaN   NaN   NaN    ND

# %%
# And see the NA snow values
# There's a lot here! Clearly snow values are not standardized.
df[df.snow.isna()]
# Out:
#           STATION                                  NAME     date  prcp  snow  \
# 128   USW00024130             BAKER CITY AIRPORT, OR US  2000-09  2.02   NaN
# 140   USW00024130             BAKER CITY AIRPORT, OR US  2001-10  0.61   NaN
# 141   USW00024130             BAKER CITY AIRPORT, OR US  2001-11  0.80   NaN
# 142   USW00024130             BAKER CITY AIRPORT, OR US  2001-12  0.95   NaN
# 143   USW00024130             BAKER CITY AIRPORT, OR US  2002-01  1.01   NaN
# ...           ...                                   ...      ...   ...   ...
# 4410  USW00024157  SPOKANE INTERNATIONAL AIRPORT, WA US  1997-07  0.80   NaN
# 4411  USW00024157  SPOKANE INTERNATIONAL AIRPORT, WA US  1997-08  0.14   NaN
# 4412  USW00024157  SPOKANE INTERNATIONAL AIRPORT, WA US  1997-09  0.92   NaN
# 4413  USW00024157  SPOKANE INTERNATIONAL AIRPORT, WA US  1997-10  1.67   NaN
# 4414  USW00024157  SPOKANE INTERNATIONAL AIRPORT, WA US  1997-11  1.99   NaN
#
#       tavg state
# 128   54.0    OR
# 140   44.0    OR
# 141   36.6    OR
# 142   24.3    OR
# 143   24.5    OR
# ...    ...   ...
# 4410  67.5    WA
# 4411  70.9    WA
# 4412  61.9    WA
# 4413  47.2    WA
# 4414  38.6    WA
#
# [2235 rows x 7 columns]

# %%
# Here, check the number of NA snow values by state
# Then normalize to years -- I want to know just how big a chunk of data is missing here
df[df.snow.isna()].groupby("state").agg({"snow": lambda x: x.isna().sum() / 12})
# Out:
#             snow
# state
# AK     23.000000
# AL      8.583333
# AR      2.083333
# AZ     20.916667
# CA     24.000000
# CO      0.583333
# CT      0.500000
# DE      3.750000
# FL     13.000000
# GA      7.666667
# HI      8.750000
# ID      0.750000
# IL      1.166667
# IN      1.000000
# KY      0.916667
# LA     15.916667
# ME      0.083333
# MI     20.750000
# MN      0.416667
# ND      0.083333
# NE      3.083333
# NM      0.750000
# OR     19.333333
# RI      3.833333
# SC      0.083333
# SD      0.166667
# TN      1.166667
# WA      1.916667
# WY      2.000000

# %%
# And see the NA temperature averages values
df[df.tavg.isna()].sort_values("date")
# Out:
#           STATION                                        NAME     date   prcp  \
# 3350  USC00072730                                DOVER, DE US  1990-05   7.81
# 1709  USC00102942                           EMMETT 2 E, ID US  1991-07    NaN
# 1006  USC00516128                MANOA LYON ARBO 785.2, HI US  1992-08    NaN
# 3380  USC00072730                                DOVER, DE US  1992-11   2.93
# 1025  USC00516128                MANOA LYON ARBO 785.2, HI US  1994-03  27.44
# 781   USW00014916    GRAND FORKS INTERNATIONAL AIRPORT, ND US  1995-02    NaN
# 701   USC00120784       BLOOMINGTON INDIANA UNIVERSITY, IN US  1997-03   3.23
# 1075  USC00516128                MANOA LYON ARBO 785.2, HI US  1998-05  13.01
# 1089  USC00516128                MANOA LYON ARBO 785.2, HI US  1999-07  18.30
# 1090  USC00516128                MANOA LYON ARBO 785.2, HI US  1999-08  10.52
# 1818  USC00102942                           EMMETT 2 E, ID US  2000-08   0.00
# 743   USC00120784       BLOOMINGTON INDIANA UNIVERSITY, IN US  2000-09   9.40
# 744   USC00120784       BLOOMINGTON INDIANA UNIVERSITY, IN US  2000-10   5.82
# 1132  USC00516128                MANOA LYON ARBO 785.2, HI US  2003-02  10.13
# 1133  USC00516128                MANOA LYON ARBO 785.2, HI US  2003-03   7.40
# 1147  USC00516128                MANOA LYON ARBO 785.2, HI US  2004-05  10.95
# 4389  USC00114530         JOLIET BRANDON ROAD LOCK DAM, IL US  2005-07   6.06
# 2396  USW00014755                     MOUNT WASHINGTON, NH US  2009-12   8.39
# 1220  USC00516128                MANOA LYON ARBO 785.2, HI US  2010-06   7.29
# 1236  USC00516128                MANOA LYON ARBO 785.2, HI US  2011-10  10.57
# 1267  USC00516128                MANOA LYON ARBO 785.2, HI US  2014-08   9.89
# 1271  USC00516128                MANOA LYON ARBO 785.2, HI US  2015-01   1.92
# 1287  USC00516128                MANOA LYON ARBO 785.2, HI US  2016-05  12.37
# 4051  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  2018-06   0.00
# 4052  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  2018-07   0.00
# 970   USC00120784       BLOOMINGTON INDIANA UNIVERSITY, IN US  2019-08    NaN
# 971   USC00120784       BLOOMINGTON INDIANA UNIVERSITY, IN US  2019-09   0.00
# 972   USC00120784       BLOOMINGTON INDIANA UNIVERSITY, IN US  2019-10    NaN
# 3708  USC00072730                                DOVER, DE US  2020-10    NaN
# 3709  USC00072730                                DOVER, DE US  2020-11    NaN
#
#       snow  tavg state
# 3350   0.0   NaN    DE
# 1709   0.0   NaN    ID
# 1006   NaN   NaN    HI
# 3380   0.0   NaN    DE
# 1025   0.0   NaN    HI
# 781    NaN   NaN    ND
# 701    0.0   NaN    IN
# 1075   0.0   NaN    HI
# 1089   0.0   NaN    HI
# 1090   0.0   NaN    HI
# 1818   0.0   NaN    ID
# 743    0.0   NaN    IN
# 744    0.0   NaN    IN
# 1132   0.0   NaN    HI
# 1133   0.0   NaN    HI
# 1147   0.0   NaN    HI
# 4389   0.0   NaN    IL
# 2396  48.2   NaN    NH
# 1220   0.0   NaN    HI
# 1236   NaN   NaN    HI
# 1267   NaN   NaN    HI
# 1271   NaN   NaN    HI
# 1287   NaN   NaN    HI
# 4051   NaN   NaN    CA
# 4052   NaN   NaN    CA
# 970    0.0   NaN    IN
# 971    0.0   NaN    IN
# 972    0.0   NaN    IN
# 3708   NaN   NaN    DE
# 3709   NaN   NaN    DE

# %% [markdown]
# Average temperatures occasionally come in sets of two or three consecutive months. But on the whole, the missing temperature values appear scattered. So it appears to me to be reasonable to fill them in by interpolation over the surrounding months.
#
# Meanwhile, precipitation is only missing a handful of data points. Snow is missing far more. For now, I just set these to zero.

# %% [markdown]
# Now resume cleaning the dataset.

# %%
# Now sort the values by state and date
df = df.sort_values(["state", "date"])
# When there are no snow measurements, assume no snow for now
# There is a LOT of missing snow data, maybe too much to impute.
df.snow = df.snow.fillna(0)
# It's not reasonable to handwave temperature away, 
# so interpolate over these values instead
# This simple approach MAY not be sufficient. May need to check:
#  (a) that linear interpolation is sufficient
#  (b) that this doesn't need to be done on a state-by-state basis
#      in order to prevent one state from affecting another's empty value
#df.tavg = df.tavg.interpolate(method="linear")

# %%
# For rain, impute the value based on the average from the same month in the adjacent years
# This process involves:
#  (1) clustering the data according to states
#  (2) reindexing the data according to the date
#  (3) creating columns to shift the data by a year in either direction. 
#       - Use freq="MS" (month start) in order to maintain compatibility with the rest of the data
#  (4) Either taking the average of two years or just taking the value of one year depending on what is available
# Print out the leftover NA PRCP values. There should be zero.

# It's not reasonable to handwave temperature away, 
# so interpolate over these values instead
# This simple approach MAY not be sufficient. May need to check:
#  (a) that linear interpolation is sufficient
#  (b) that this doesn't need to be done on a state-by-state basis
#      in order to prevent one state from affecting another's empty value

state_dfs = [df[df.state==x].copy() for x in df.state.unique()]
state_dfs_shifted = []
for dfi in state_dfs:
    # Reindex
    dfi.date = pd.to_datetime(dfi.date)
    dfi = dfi.set_index("date")
    #dfi = dfi.index.rename("dateid")
    # Impute
    dfi["prcp_minus"] = dfi.prcp.shift(-12, freq="MS")
    dfi["prcp_plus"] = dfi.prcp.shift(12, freq="MS")
    dfi.prcp = dfi.prcp.fillna((dfi.prcp_minus + dfi.prcp_plus) / 2.0)
    dfi.prcp = dfi.prcp.fillna(dfi.prcp_minus)
    dfi.prcp = dfi.prcp.fillna(dfi.prcp_plus)
    # Interpolate
    dfi.tavg = dfi.tavg.interpolate(method="linear")
    state_dfs_shifted.append(dfi)
shifted_df = pd.concat(state_dfs_shifted)
print("Number of zero precipitation elements:", len(shifted_df[shifted_df.prcp.isna()]))
print("Number of zero temperature elements:", len(shifted_df[shifted_df.tavg.isna()]))
shifted_df
# Out:
# Number of zero precipitation elements: 0
# Number of zero temperature elements: 0
#                 STATION                              NAME  prcp  snow  tavg  \
# date
# 1990-01-01  USW00026528          TALKEETNA AIRPORT, AK US  3.63  60.2   9.3
# 1990-02-01  USW00026528          TALKEETNA AIRPORT, AK US  4.31  60.3  -4.2
# 1990-03-01  USW00026528          TALKEETNA AIRPORT, AK US  3.94  43.7  26.8
# 1990-04-01  USW00026528          TALKEETNA AIRPORT, AK US  0.93   2.1  38.1
# 1990-05-01  USW00026528          TALKEETNA AIRPORT, AK US  1.61   0.0  49.2
# ...                 ...                               ...   ...   ...   ...
# 2019-08-01  USW00024089  CASPER NATRONA CO AIRPORT, WY US  0.17   0.0  69.7
# 2019-09-01  USW00024089  CASPER NATRONA CO AIRPORT, WY US  1.42   0.0  61.4
# 2019-10-01  USW00024089  CASPER NATRONA CO AIRPORT, WY US  1.30  13.9  36.9
# 2019-11-01  USW00024089  CASPER NATRONA CO AIRPORT, WY US  1.86  18.9  31.1
# 2019-12-01  USW00024089  CASPER NATRONA CO AIRPORT, WY US  0.60   8.0  26.8
#
#            state  prcp_minus  prcp_plus
# date
# 1990-01-01    AK        2.34        NaN
# 1990-02-01    AK        0.63        NaN
# 1990-03-01    AK        3.29        NaN
# 1990-04-01    AK        1.02        NaN
# 1990-05-01    AK        1.05        NaN
# ...          ...         ...        ...
# 2019-08-01    WY         NaN       0.33
# 2019-09-01    WY         NaN       0.28
# 2019-10-01    WY         NaN       1.69
# 2019-11-01    WY         NaN       0.94
# 2019-12-01    WY         NaN       0.41
#
# [18008 rows x 8 columns]

# %%
# If we're happy with the above, we can replace the dataset wholesale
df = shifted_df
#df["date"] = shifted_df.index.strftime('%Y-%m')
df.sample()
# Out:
#                 STATION                                               NAME  \
# date
# 1998-01-01  USW00013874  ATLANTA HARTSFIELD JACKSON INTERNATIONAL AIRPO...
#
#             prcp  snow  tavg state  prcp_minus  prcp_plus
# date
# 1998-01-01  5.84   0.0  46.0    GA        5.33       5.65

# %%
# And now verify there are no other NA values
# (We don't care about prcp_plus and prcp_minus -- they served their purpose)
df.isna().sum()
# Out:
# STATION         0
# NAME            0
# prcp            0
# snow            0
# tavg            0
# state           0
# prcp_minus    641
# prcp_plus     637
# dtype: int64

# %%
# Write out a new CSV file, sorted by state and date
features = ["state", "prcp", "snow", "tavg"]
new_df = df[features].sort_values(["state", "date"])
new_df.to_csv("monthly-weather-1990-2019-final.csv", date_format='%Y-%m')

# %% [markdown]
# Finally, make some plots of these features to make sure they make sense. This should also expose any non-numeric values that may have snuck past.

# %%
plt.plot(new_df[new_df.state=="NY"].index.date, new_df[new_df.state=="NY"].prcp)
plt.title("Precipitation at New York Facility")
plt.xlabel("Month")
plt.ylabel("Precipitation (in)")
# Out:
# Text(0, 0.5, 'Precipitation (in)')

# %%
plt.plot(new_df[new_df.state=="NY"].index.date, new_df[new_df.state=="NY"].snow)
plt.title("Snow at New York Facility")
plt.xlabel("Month")
plt.ylabel("Snow (in)")
# Out:
# Text(0, 0.5, 'Snow (in)')

# %%
plt.plot(new_df[new_df.state=="NY"].index.date, new_df[new_df.state=="NY"].tavg)
plt.title("Average Temperature at New York Facility")
plt.xlabel("Month")
plt.ylabel("Temperature (degrees Fahrenheit)")
# Out:
# Text(0, 0.5, 'Temperature (degrees Fahrenheit)')

# %% [markdown]
# Now check another state that is not New York for comparison.

# %%
full_names = [
    "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia",
    "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland",
    "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey",
    "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina",
    "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"
]

def check_state(state_abbrev):
    #plt.title("Precipitation at New York Facility")
    #plt.xlabel("Month")
    #plt.ylabel("Precipitation (in)")

    plt.rcParams['text.usetex'] = True

    # Information on doing this here: 
    # https://matplotlib.org/stable/gallery/subplots_axes_and_figures/ganged_plots.html
    fig, axs = plt.subplots(3, 1, sharex=True)
    fig.subplots_adjust(hspace=0)
    fig.set_size_inches((10,6))

    df_plot = new_df[new_df.state==state_abbrev]
    x = df_plot.index.date

    axs[0].plot(x, df_plot.prcp)
    axs[0].set_title(f"Weather Data for {full_names[abbreviations.index(state_abbrev)]}")
    axs[0].set_ylabel("Total Monthly\nPrecipitation (in)")

    axs[1].plot(x, df_plot.snow)
    axs[1].set_ylabel("Total Monthly\nSnow (in)")

    axs[2].plot(x, df_plot.tavg)
    axs[2].set_ylabel("Average Monthly\nTemperature ($^\\circ$F)")

# %%
check_state("NY")

# %%
check_state("AK")

# %% [markdown]
# As suspected from earlier analysis, we're missing huge chunks of Alaska snow here, and it seems unlikely that Alaska simply stopped receiving snow.

# %%
check_state("MN")
